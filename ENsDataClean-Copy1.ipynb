# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ens = pd.read_excel(r"C:\Users\CEN1\OneDrive - U.S. NRC\CEN1\GAData\ENsRaw.xlsx", index_col=0)

# %%
ens.head(20)
# Out:
#                      EventNotificationNumber  RevisionNumber  \
# EventNotificationId
# 18700                                  18715             NaN
# 18701                                  18716             NaN
# 18702                                  18717             NaN
# 18703                                  18718             NaN
# 18704                                  18719             NaN
# 18705                                  18720             NaN
# 18706                                  18721             NaN
# 18707                                  18722             NaN
# 18708                                  18723             NaN
# 18709                                  18724             NaN
# 18710                                  18725             NaN
# 18711                                  18726             NaN
# 18712                                  18727             NaN
# 18713                                  18728             NaN
# ...

# %%
ens.dtypes
# Out:
# EventNotificationNumber             int64
# RevisionNumber                    float64
# RetractIndicator                    int64
# SiteName                           object
# UnitInd1                          float64
#                                 ...
# ImportedDate               datetime64[ns]
# OfInterest                           bool
# Interest                           object
# DocketNumber2                      object
# DocketNumber3                     float64
# Length: 86, dtype: object

# %%
ens.shape
# Out:
# (54772, 86)

# %%
#I only want the items of document type "POW" for this analysis as those are the power reactors
ens_pow = ens.loc[ens['DocumentTypeCode'] == 'POW']

# %%
ens_pow['SiteName'].unique()
# Out:
# array(['FT CALHOUN', 'PALISADES', 'YANKEE ROWE', 'NORTH ANNA',
#        'MILLSTONE', 'QUAD CITIES', 'SOUTH TEXAS', 'SUSQUEHANNA',
#        'HUMBOLDT BAY', 'LASALLE', 'SAINT LUCIE', 'HATCH', 'ROBINSON',
#        'TROJAN', 'POINT BEACH', 'NINE MILE POINT', 'PEACH BOTTOM',
#        'FERMI', 'PERRY', 'PALO VERDE', 'SEABROOK', 'INDIAN POINT',
#        'BEAVER VALLEY', 'BROWNS FERRY', 'VOGTLE', 'PRAIRIE ISLAND',
#        'CALVERT CLIFFS', 'MAINE YANKEE', 'BRAIDWOOD', 'CATAWBA', 'SALEM',
#        'WATERFORD', 'TURKEY POINT', 'HADDAM NECK', 'COOK', 'BRUNSWICK',
#        'ZION', 'LIMERICK', 'VERMONT YANKEE', 'HARRIS', 'FARLEY',
#        'MCGUIRE', 'SUMMER', 'CLINTON', 'SEQUOYAH', 'COMANCHE PEAK',
#        'ARKANSAS NUCLEAR', 'WASHINGTON NUCLEAR', 'CRYSTAL RIVER',
#        'HOPE CREEK', 'GINNA', 'FITZPATRICK', 'MONTICELLO', 'DRESDEN',
#        'SAN ONOFRE', 'DIABLO CANYON', 'RIVER BEND', 'COOPER',
#        'OYSTER CREEK', 'THREE MILE ISLAND', 'DUANE ARNOLD', 'SHOREHAM',
# ...

# %%
ens_pow['SiteName'] = ens_pow['SiteName'].str.upper()
# Out:
# C:\Users\CEN1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ens_pow["SiteName"] = ens_pow["SiteName"].map({
        'FT CALHOUN': 'FORT CALHOUN',
        'ARKANSAS NUCLEAR': 'ARKANSAS NUCLEAR ONE',
        'COLUMBIA GENERATING STATION': 'COLUMBIA',
        }).fillna(ens_pow["SiteName"])
# Out:
# C:\Users\CEN1\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
ens_pow = ens_pow[(ens_pow.SiteName != "LACROSSE") & (ens_pow.SiteName != "RANCHO SECO") & (ens_pow.SiteName !="ZION") & (ens_pow.SiteName != "BELLEFONTE") & (ens_pow.SiteName != "HUMBOLDT BAY") & 
                      (ens_pow.SiteName != "HADDAM NECK") & (ens_pow.SiteName != "MAINE YANKEE") & 
                              (ens_pow.SiteName != "BIG ROCK POINT") & (ens_pow.SiteName != "TROJAN") & 
                              (ens_pow.SiteName != "FT SAINT VRAIN") & (ens_pow.SiteName != "WNP-2") & 
                              (ens_pow.SiteName != "WASHINGTON NUCLEAR") & (ens_pow.SiteName != "WASHINGTON NUCLEAR (WNP-2)") & 
                              (ens_pow.SiteName != "SHOREHAM") & 
                              (ens_pow.SiteName != "YANKEE ROWE") &
                              (ens_pow.SiteName != "SUMMER CONTRUCTION")]

# %%
ens_pow['UnitName'] = (ens_pow['SiteName'] + ' ' + ens_pow['UnitInd1'].astype(str) + ' ' + ens_pow['UnitInd2'].astype(str) + ' ' + ens_pow['UnitInd3'].astype(str))
#ens['UnitName'] = pd.Series(ens['SiteName'],ens['UnitInd1'].astype(str),ens['UnitInd2'].astype(str),ens['UnitInd3'].astype(str)).cat(sep=' ')

# %%
ens_pow.head()
# Out:
#                      EventNotificationNumber  RevisionNumber  \
# EventNotificationId
# 18701                                  18716             NaN
# 18702                                  18717             NaN
# 18704                                  18719             NaN
# 18705                                  18720             NaN
# 18706                                  18721             NaN
#
#                      RetractIndicator      SiteName  UnitInd1  UnitInd2  \
# EventNotificationId
# 18701                               0  FORT CALHOUN       1.0       NaN
# 18702                               0     PALISADES       1.0       NaN
# 18704                              -1    NORTH ANNA       1.0       2.0
# 18705                               0     MILLSTONE       NaN       2.0
# 18706                               0   QUAD CITIES       1.0       2.0
#
#                      UnitInd3                      RxType NrcNotifiedBy  \
# EventNotificationId
# ...

# %%
ens_pow['RealName'] = ens_pow['UnitName'].str.replace('nan', '')

# %%
ens_pow['NameAgain'] = ens_pow['RealName'].str.replace('.0', '')

# %%
ens_pow.head()
# Out:
#                      EventNotificationNumber  RevisionNumber  \
# EventNotificationId
# 18701                                  18716             NaN
# 18702                                  18717             NaN
# 18704                                  18719             NaN
# 18705                                  18720             NaN
# 18706                                  18721             NaN
#
#                      RetractIndicator      SiteName  UnitInd1  UnitInd2  \
# EventNotificationId
# 18701                               0  FORT CALHOUN       1.0       NaN
# 18702                               0     PALISADES       1.0       NaN
# 18704                              -1    NORTH ANNA       1.0       2.0
# 18705                               0     MILLSTONE       NaN       2.0
# 18706                               0   QUAD CITIES       1.0       2.0
#
#                      UnitInd3                      RxType NrcNotifiedBy  \
# EventNotificationId
# ...

# %%
ens_pow['NameAgain'].unique()
# Out:
# array(['FORT CALHOUN 1  ', 'PALISADES 1  ', 'NORTH ANNA 1 2 ',
#        'MILLSTONE  2 ', 'QUAD CITIES 1 2 ', 'SOUTH TEXAS 1  ',
#        'SUSQUEHANNA 1  ', 'LASALLE 1  ', 'SAINT LUCIE 1 2 ', 'HATCH 1  ',
#        'ROBINSON 2  ', 'POINT BEACH 1  ', 'MILLSTONE 1  ',
#        'NINE MILE POINT 1 2 ', 'PEACH BOTTOM 2  ', 'FERMI 2  ',
#        'MILLSTONE   3', 'PERRY 1  ', 'PEACH BOTTOM  3 ', 'PALO VERDE 1  ',
#        'SEABROOK 1  ', 'PEACH BOTTOM 2 3 ', 'SUSQUEHANNA  2 ',
#        'INDIAN POINT 2  ', 'NINE MILE POINT  2 ', 'BEAVER VALLEY  2 ',
#        'LASALLE  2 ', 'PALO VERDE  2 ', 'BROWNS FERRY 1  ', 'VOGTLE 1 2 ',
#        'PRAIRIE ISLAND 1  ', 'CALVERT CLIFFS 1 2 ', 'NINE MILE POINT 1  ',
#        'QUAD CITIES 1  ', 'BRAIDWOOD 1  ', 'POINT BEACH 1 2 ',
#        'CATAWBA  2 ', 'SALEM 1  ', 'WATERFORD 3  ', 'TURKEY POINT  4 ',
#        'COOK 1 2 ', 'BRUNSWICK 1 2 ', 'LIMERICK 1  ', 'HATCH  2 ',
#        'INDIAN POINT  3 ', 'VERMONT YANKEE 1  ', 'SALEM  2 ',
# ...

# %%
ens_pow['NameAgain'] = ens_pow['NameAgain'].str.strip()

# %%
ens_pow.head()
# Out:
#                      EventNotificationNumber  RevisionNumber  \
# EventNotificationId
# 18701                                  18716             NaN
# 18702                                  18717             NaN
# 18704                                  18719             NaN
# 18705                                  18720             NaN
# 18706                                  18721             NaN
#
#                      RetractIndicator      SiteName  UnitInd1  UnitInd2  \
# EventNotificationId
# 18701                               0  FORT CALHOUN       1.0       NaN
# 18702                               0     PALISADES       1.0       NaN
# 18704                              -1    NORTH ANNA       1.0       2.0
# 18705                               0     MILLSTONE       NaN       2.0
# 18706                               0   QUAD CITIES       1.0       2.0
#
#                      UnitInd3                      RxType NrcNotifiedBy  \
# EventNotificationId
# ...

# %%
ens_pow['NameAgain'].unique()
# Out:
# array(['FORT CALHOUN 1', 'PALISADES 1', 'NORTH ANNA 1 2', 'MILLSTONE  2',
#        'QUAD CITIES 1 2', 'SOUTH TEXAS 1', 'SUSQUEHANNA 1', 'LASALLE 1',
#        'SAINT LUCIE 1 2', 'HATCH 1', 'ROBINSON 2', 'POINT BEACH 1',
#        'MILLSTONE 1', 'NINE MILE POINT 1 2', 'PEACH BOTTOM 2', 'FERMI 2',
#        'MILLSTONE   3', 'PERRY 1', 'PEACH BOTTOM  3', 'PALO VERDE 1',
#        'SEABROOK 1', 'PEACH BOTTOM 2 3', 'SUSQUEHANNA  2',
#        'INDIAN POINT 2', 'NINE MILE POINT  2', 'BEAVER VALLEY  2',
#        'LASALLE  2', 'PALO VERDE  2', 'BROWNS FERRY 1', 'VOGTLE 1 2',
#        'PRAIRIE ISLAND 1', 'CALVERT CLIFFS 1 2', 'NINE MILE POINT 1',
#        'QUAD CITIES 1', 'BRAIDWOOD 1', 'POINT BEACH 1 2', 'CATAWBA  2',
#        'SALEM 1', 'WATERFORD 3', 'TURKEY POINT  4', 'COOK 1 2',
#        'BRUNSWICK 1 2', 'LIMERICK 1', 'HATCH  2', 'INDIAN POINT  3',
#        'VERMONT YANKEE 1', 'SALEM  2', 'HARRIS 1', 'BEAVER VALLEY 1 2',
#        'FARLEY 1 2', 'MCGUIRE  2', 'SUMMER 1', 'CLINTON 1',
# ...

# %%
ens_pow['NameAgain'] = ens_pow['NameAgain'].str.replace('  ', ' ')

# %%
ens_pow['NameAgain'].unique()
# Out:
# array(['FORT CALHOUN 1', 'PALISADES 1', 'NORTH ANNA 1 2', 'MILLSTONE 2',
#        'QUAD CITIES 1 2', 'SOUTH TEXAS 1', 'SUSQUEHANNA 1', 'LASALLE 1',
#        'SAINT LUCIE 1 2', 'HATCH 1', 'ROBINSON 2', 'POINT BEACH 1',
#        'MILLSTONE 1', 'NINE MILE POINT 1 2', 'PEACH BOTTOM 2', 'FERMI 2',
#        'MILLSTONE  3', 'PERRY 1', 'PEACH BOTTOM 3', 'PALO VERDE 1',
#        'SEABROOK 1', 'PEACH BOTTOM 2 3', 'SUSQUEHANNA 2',
#        'INDIAN POINT 2', 'NINE MILE POINT 2', 'BEAVER VALLEY 2',
#        'LASALLE 2', 'PALO VERDE 2', 'BROWNS FERRY 1', 'VOGTLE 1 2',
#        'PRAIRIE ISLAND 1', 'CALVERT CLIFFS 1 2', 'NINE MILE POINT 1',
#        'QUAD CITIES 1', 'BRAIDWOOD 1', 'POINT BEACH 1 2', 'CATAWBA 2',
#        'SALEM 1', 'WATERFORD 3', 'TURKEY POINT 4', 'COOK 1 2',
#        'BRUNSWICK 1 2', 'LIMERICK 1', 'HATCH 2', 'INDIAN POINT 3',
#        'VERMONT YANKEE 1', 'SALEM 2', 'HARRIS 1', 'BEAVER VALLEY 1 2',
#        'FARLEY 1 2', 'MCGUIRE 2', 'SUMMER 1', 'CLINTON 1', 'BRUNSWICK 2',
# ...

# %%
ens_pow['NameAgain'].sort_values(ascending=True).unique()
# Out:
# array(['ARKANSAS NUCLEAR ONE 1', 'ARKANSAS NUCLEAR ONE 1 2',
#        'ARKANSAS NUCLEAR ONE 2', 'BEAVER VALLEY 1', 'BEAVER VALLEY 1 2',
#        'BEAVER VALLEY 2', 'BRAIDWOOD 1', 'BRAIDWOOD 1 2', 'BRAIDWOOD 2',
#        'BROWNS FERRY  3', 'BROWNS FERRY 1', 'BROWNS FERRY 1 2',
#        'BROWNS FERRY 1 2 3', 'BROWNS FERRY 1 3', 'BROWNS FERRY 2',
#        'BROWNS FERRY 2 3', 'BRUNSWICK 1', 'BRUNSWICK 1 2', 'BRUNSWICK 2',
#        'BYRON', 'BYRON 1', 'BYRON 1 2', 'BYRON 2', 'CALLAWAY 1',
#        'CALVERT CLIFFS 1', 'CALVERT CLIFFS 1 2', 'CALVERT CLIFFS 2',
#        'CATAWBA', 'CATAWBA 1', 'CATAWBA 1 2', 'CATAWBA 2', 'CLINTON 1',
#        'COLUMBIA 2', 'COMANCHE PEAK 1', 'COMANCHE PEAK 1 2',
#        'COMANCHE PEAK 2', 'COOK 1', 'COOK 1 2', 'COOK 2', 'COOPER 1',
#        'CRYSTAL RIVER 3', 'DAVIS BESSE 1', 'DIABLO CANYON 1',
#        'DIABLO CANYON 1 2', 'DIABLO CANYON 2', 'DRESDEN  3', 'DRESDEN 1',
#        'DRESDEN 1 2', 'DRESDEN 1 2 3', 'DRESDEN 2', 'DRESDEN 2 3',
# ...

# %%
ens_pow['NameAgain'] = ens_pow['NameAgain'].str.replace('1 2', '1')
ens_pow['NameAgain'] = ens_pow['NameAgain'].str.replace('2 3', '2')
ens_pow['NameAgain'] = ens_pow['NameAgain'].str.replace('1 3', '1')
ens_pow['NameAgain'] = ens_pow['NameAgain'].str.replace('3 4', '3')
ens_pow['NameAgain'] = ens_pow['NameAgain'].str.replace('1 2 3', '1')
ens_pow['NameAgain'] = ens_pow['NameAgain'].str.replace('  3', ' 3')

# %%
ens_pow["NameAgain"] = ens_pow["NameAgain"].map({
        'BYRON': 'BYRON 1',
        'CATAWBA': 'CATAWBA 1',
        'DAVIS BESSE 1': 'DAVIS-BESSE',
        'LASALLE': 'LASALLE 1',
        'MCGUIRE': 'MCGUIRE 1',
        'MILLSTONE': 'MILLSTONE 1',
        'QUAD CITIES': 'QUAD CITIES 1',
        'SALEM': 'SALEM 1',
        'VOGTLE': 'VOGTLE 1'
        }).fillna(ens_pow["NameAgain"])

# %%
ens_pow['NameAgain'].sort_values(ascending=True).unique()
# Out:
# array(['ARKANSAS NUCLEAR ONE 1', 'ARKANSAS NUCLEAR ONE 2',
#        'BEAVER VALLEY 1', 'BEAVER VALLEY 2', 'BRAIDWOOD 1', 'BRAIDWOOD 2',
#        'BROWNS FERRY 1', 'BROWNS FERRY 2', 'BROWNS FERRY 3',
#        'BRUNSWICK 1', 'BRUNSWICK 2', 'BYRON 1', 'BYRON 2', 'CALLAWAY 1',
#        'CALVERT CLIFFS 1', 'CALVERT CLIFFS 2', 'CATAWBA 1', 'CATAWBA 2',
#        'CLINTON 1', 'COLUMBIA 2', 'COMANCHE PEAK 1', 'COMANCHE PEAK 2',
#        'COOK 1', 'COOK 2', 'COOPER 1', 'CRYSTAL RIVER 3', 'DAVIS-BESSE',
#        'DIABLO CANYON 1', 'DIABLO CANYON 2', 'DRESDEN 1', 'DRESDEN 2',
#        'DRESDEN 3', 'DUANE ARNOLD 1', 'FARLEY 1', 'FARLEY 2', 'FERMI 2',
#        'FITZPATRICK 1', 'FORT CALHOUN 1', 'GINNA 1', 'GRAND GULF 1',
#        'HARRIS 1', 'HATCH 1', 'HATCH 2', 'HOPE CREEK 1', 'INDIAN POINT 2',
#        'INDIAN POINT 3', 'KEWAUNEE 1', 'LASALLE 1', 'LASALLE 2',
#        'LIMERICK 1', 'LIMERICK 2', 'MCGUIRE 1', 'MCGUIRE 2',
#        'MILLSTONE 1', 'MILLSTONE 2', 'MILLSTONE 3', 'MONTICELLO 1',
# ...

# %%
ens_pow["NameAgain"] = ens_pow["NameAgain"].map({
        'ARKANSAS NUCLEAR ONE 1': 'ARKANSAS NUCLEAR 1',
        'ARKANSAS NUCLEAR ONE 2': 'ARKANSAS NUCLEAR 2',
        'CALLAWAY 1': 'CALLAWAY',
        'CLINTON 1': 'CLINTON',
        'COLUMBIA 2': 'COLUMBIA GENERATING STATION',
        'COOK 1': 'D.C. COOK 1',
        'COOK 2': 'D.C. COOK 2',
        'COOPER 1': 'COOPER',
        'DAVIS BESSE 1': 'DAVIS-BESSE',
        'DUANE ARNOLD 1': 'DUANE ARNOLD',
        'FITZPATRICK 1': 'FITZPATRICK',
        'FORT CALHOUN 1': 'FORT CALHOUN',
        'GINNA 1': 'GINNA',
        'LASALLE': 'LASALLE 1',
        'MCGUIRE': 'MCGUIRE 1',
        'MILLSTONE': 'MILLSTONE 1',
        'MONTICELLO 1': 'MONTICELLO',
        'OYSTER CREEK 1': 'OYSTER CREEK',
        'PALISADES 1': 'PALISADES',
        'QUAD CITIES': 'QUAD CITIES 1',
        'SALEM': 'SALEM 1',
        'SUMMER 1': 'SUMMER',
        'VERMONT YANKEE 1': 'VERMONT YANKEE',
        'VOGTLE': 'VOGTLE 1'
        }).fillna(ens_pow["NameAgain"])

# %%
ens_pow = ens_pow[(ens_pow.NameAgain != "DRESDEN 1") & (ens_pow.NameAgain != "MILLSTONE 1") & (ens_pow.NameAgain !="NORTH ANNA 3") & (ens_pow.NameAgain != "SAN ONOFRE 1") & (ens_pow.NameAgain != "SUMMER 2") & 
                      (ens_pow.NameAgain != "SUMMER CONSTRUCTION 2") & (ens_pow.NameAgain != "THREE MILE ISLAND 2") & 
                              (ens_pow.NameAgain != "VOGTLE 3") & (ens_pow.NameAgain != "VOGTLE 4")]

# %%
ens_pow['NameAgain'].sort_values(ascending=True).unique()
# Out:
# array(['ARKANSAS NUCLEAR 1', 'ARKANSAS NUCLEAR 2', 'BEAVER VALLEY 1',
#        'BEAVER VALLEY 2', 'BRAIDWOOD 1', 'BRAIDWOOD 2', 'BROWNS FERRY 1',
#        'BROWNS FERRY 2', 'BROWNS FERRY 3', 'BRUNSWICK 1', 'BRUNSWICK 2',
#        'BYRON 1', 'BYRON 2', 'CALLAWAY', 'CALVERT CLIFFS 1',
#        'CALVERT CLIFFS 2', 'CATAWBA 1', 'CATAWBA 2', 'CLINTON',
#        'COLUMBIA GENERATING STATION', 'COMANCHE PEAK 1',
#        'COMANCHE PEAK 2', 'COOPER', 'CRYSTAL RIVER 3', 'D.C. COOK 1',
#        'D.C. COOK 2', 'DAVIS-BESSE', 'DIABLO CANYON 1', 'DIABLO CANYON 2',
#        'DRESDEN 2', 'DRESDEN 3', 'DUANE ARNOLD', 'FARLEY 1', 'FARLEY 2',
#        'FERMI 2', 'FITZPATRICK', 'FORT CALHOUN', 'GINNA', 'GRAND GULF 1',
#        'HARRIS 1', 'HATCH 1', 'HATCH 2', 'HOPE CREEK 1', 'INDIAN POINT 2',
#        'INDIAN POINT 3', 'KEWAUNEE 1', 'LASALLE 1', 'LASALLE 2',
#        'LIMERICK 1', 'LIMERICK 2', 'MCGUIRE 1', 'MCGUIRE 2',
#        'MILLSTONE 2', 'MILLSTONE 3', 'MONTICELLO', 'NINE MILE POINT 1',
# ...

# %%
ens_pow.dtypes
# Out:
# EventNotificationNumber      int64
# RevisionNumber             float64
# RetractIndicator             int64
# SiteName                    object
# UnitInd1                   float64
#                             ...
# DocketNumber2               object
# DocketNumber3              float64
# UnitName                    object
# RealName                    object
# NameAgain                   object
# Length: 89, dtype: object

# %%
ens_pow['NameAgain'].isnull().sum()
# Out:
# 0

# %%
ens_pow.shape
# Out:
# (39081, 89)

# %%
ens_pow.columns
# Out:
# Index(['EventNotificationNumber', 'RevisionNumber', 'RetractIndicator',
#        'SiteName', 'UnitInd1', 'UnitInd2', 'UnitInd3', 'RxType',
#        'NrcNotifiedBy', 'OperationsOfficer', 'EventDate', 'NotificationDate',
#        'DateUpdated', 'StaffName1', 'StaffName2', 'StaffName3', 'StaffName4',
#        'StaffName5', 'StaffName6', 'StaffName7', 'StaffName8', 'StaffName9',
#        'StaffName10', 'OrgAbbreviation1', 'OrgAbbreviation2',
#        'OrgAbbreviation3', 'OrgAbbreviation4', 'OrgAbbreviation5',
#        'OrgAbbreviation6', 'OrgAbbreviation7', 'OrgAbbreviation8',
#        'OrgAbbreviation9', 'OrgAbbreviation10', 'Text', 'CurrPower1',
#        'CurrPower2', 'CurrPower3', 'InitPower1', 'InitPower2', 'InitPower3',
#        'CriticalIndicator1', 'CriticalIndicator2', 'CriticalIndicator3',
#        'ScramType1', 'ScramType2', 'ScramType3', 'EventDescription',
#        'CfrDescription1', 'CfrDescription2', 'CfrDescription3',
# ...

# %%
#choosing just the columns that I believe I will need for this analysis
ens_clean = ens_pow[['EventNotificationNumber', 'SiteName', 'EventDate', 'NotificationDate', 'Text', 'CurrPower1', 'CurrPower2', 'CurrPower3', 'InitPower1', 'InitPower2', 'InitPower3', 'ImportedDate', 'NameAgain']]

# %%
ens_clean.shape
# Out:
# (39081, 13)

# %%
ens_clean.dtypes
# Out:
# EventNotificationNumber             int64
# SiteName                           object
# EventDate                  datetime64[ns]
# NotificationDate           datetime64[ns]
# Text                               object
# CurrPower1                        float64
# CurrPower2                        float64
# CurrPower3                        float64
# InitPower1                        float64
# InitPower2                        float64
# InitPower3                        float64
# ImportedDate               datetime64[ns]
# NameAgain                          object
# dtype: object

# %%
ens_clean.head()
# Out:
#                      EventNotificationNumber      SiteName  \
# EventNotificationId
# 18701                                  18716  FORT CALHOUN
# 18702                                  18717     PALISADES
# 18704                                  18719    NORTH ANNA
# 18705                                  18720     MILLSTONE
# 18706                                  18721   QUAD CITIES
#
#                               EventDate    NotificationDate  \
# EventNotificationId
# 18701               1990-06-15 18:24:00 1990-06-15 18:24:00
# 18702               1990-06-15 20:10:00 1990-06-15 22:49:00
# 18704               1990-06-16 14:53:00 1990-06-16 18:47:00
# 18705               1990-06-17 01:18:00 1990-06-17 02:25:00
# 18706               1990-06-17 03:13:00 1990-06-17 04:48:00
#
#                                                                   Text  \
# EventNotificationId
# 18701                LICENSEE PLANS TO DISABLE THE CONTROL ROOM ENS...
# ...

# %%
ens_clean.loc[48072]
# Out:
# EventNotificationNumber                                                49195
# SiteName                                                             CATAWBA
# EventDate                                                                NaT
# NotificationDate                                         2013-07-16 14:20:00
# Text                       60 DAY REPORT - INVALID ACTUATION OF SPECIFIED...
# CurrPower1                                                               100
# CurrPower2                                                               100
# CurrPower3                                                                 0
# InitPower1                                                               100
# InitPower2                                                               100
# InitPower3                                                                 0
# ImportedDate                                      2018-06-13 12:25:01.117000
# ...

# %%
ens_clean.head()
# Out:
#                      EventNotificationNumber      SiteName  \
# EventNotificationId
# 18701                                  18716  FORT CALHOUN
# 18702                                  18717     PALISADES
# 18704                                  18719    NORTH ANNA
# 18705                                  18720     MILLSTONE
# 18706                                  18721   QUAD CITIES
#
#                               EventDate    NotificationDate  \
# EventNotificationId
# 18701               1990-06-15 18:24:00 1990-06-15 18:24:00
# 18702               1990-06-15 20:10:00 1990-06-15 22:49:00
# 18704               1990-06-16 14:53:00 1990-06-16 18:47:00
# 18705               1990-06-17 01:18:00 1990-06-17 02:25:00
# 18706               1990-06-17 03:13:00 1990-06-17 04:48:00
#
#                                                                   Text  \
# EventNotificationId
# 18701                LICENSEE PLANS TO DISABLE THE CONTROL ROOM ENS...
# ...

# %%
ens_clean["EventDate"].unique()
# Out:
# array(['1990-06-15T18:24:00.000000000', '1990-06-15T20:10:00.000000000',
#        '1990-06-16T14:53:00.000000000', ...,
#        '1990-06-14T15:55:00.000000000', '1990-06-15T09:50:00.000000000',
#        '1990-06-15T12:03:00.000000000'], dtype='datetime64[ns]')

# %%
#checking out a specific row as a spot check
ens_clean.loc[48064]
# Out:
# EventNotificationNumber                                                49187
# SiteName                                                             PILGRIM
# EventDate                                                                NaT
# NotificationDate                                         2013-07-11 19:49:00
# Text                       FITNESS-FOR-DUTY REPORT INVOLVING A NON-LICENS...
# CurrPower1                                                               100
# CurrPower2                                                                 0
# CurrPower3                                                                 0
# InitPower1                                                               100
# InitPower2                                                                 0
# InitPower3                                                                 0
# ImportedDate                                      2018-06-13 12:25:01.087000
# ...

# %%
#creating a new column of Year to make the EventDate column just the date
ens_clean['Year'] = ens_clean['EventDate'].astype(str).str[:10]
# Out:
# C:\Users\CEN1\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#ens_clean['IntEventDate'] = ens_clean['Year'].str.replace("-","")
# Out:
# C:\Users\CEN1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ens_clean.head()
# Out:
#                      EventNotificationNumber      SiteName  \
# EventNotificationId
# 18701                                  18716  FORT CALHOUN
# 18702                                  18717     PALISADES
# 18704                                  18719    NORTH ANNA
# 18705                                  18720     MILLSTONE
# 18706                                  18721   QUAD CITIES
#
#                               EventDate    NotificationDate  \
# EventNotificationId
# 18701               1990-06-15 18:24:00 1990-06-15 18:24:00
# 18702               1990-06-15 20:10:00 1990-06-15 22:49:00
# 18704               1990-06-16 14:53:00 1990-06-16 18:47:00
# 18705               1990-06-17 01:18:00 1990-06-17 02:25:00
# 18706               1990-06-17 03:13:00 1990-06-17 04:48:00
#
#                                                                   Text  \
# EventNotificationId
# 18701                LICENSEE PLANS TO DISABLE THE CONTROL ROOM ENS...
# ...

# %%
ens_clean['Year'].isnull().sum()
# Out:
# 0

# %%
#ens_clean['IntEventDate'].isnull().sum()
# Out:
# 0

# %%
(ens_clean['Year'] == "NaT").sum()
# Out:
# 43

# %%
(ens_clean['EventDate'] == "NaT").sum()
# Out:
# 0

# %%
#looking for where NaT exists in my IntEventDate created column because it matches where it is in EventDate column
nullintdate = (ens_clean['Year'] == "NaT")
ens_clean[nullintdate].head(44)
# Out:
#                      EventNotificationNumber              SiteName EventDate  \
# EventNotificationId
# 7100                                    6804              CALLAWAY       NaT
# 48045                                  49168             BRUNSWICK       NaT
# 48046                                  49169            PALO VERDE       NaT
# 48047                                  49170                  COOK       NaT
# 48048                                  49171          INDIAN POINT       NaT
# 48049                                  49172             MILLSTONE       NaT
# 48050                                  49173         DIABLO CANYON       NaT
# 48051                                  49174               LASALLE       NaT
# 48053                                  49176       NINE MILE POINT       NaT
# 48054                                  49177                 GINNA       NaT
# 48055                                  49178           SAINT LUCIE       NaT
# ...

# %%
#assigning the notification date to the event date where there is no value for event date
ens_clean.loc[nullintdate, "EventDate"] = ens_clean.loc[nullintdate, "NotificationDate"]
# Out:
# C:\Users\CEN1\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
ens_clean[nullintdate].head(44)
# Out:
#                      EventNotificationNumber              SiteName  \
# EventNotificationId
# 7100                                    6804              CALLAWAY
# 48045                                  49168             BRUNSWICK
# 48046                                  49169            PALO VERDE
# 48047                                  49170                  COOK
# 48048                                  49171          INDIAN POINT
# 48049                                  49172             MILLSTONE
# 48050                                  49173         DIABLO CANYON
# 48051                                  49174               LASALLE
# 48053                                  49176       NINE MILE POINT
# 48054                                  49177                 GINNA
# 48055                                  49178           SAINT LUCIE
# 48056                                  49179           FITZPATRICK
# 48058                                  49181            MONTICELLO
# ...

# %%
#there are 10 rows where the notification date and event date do not match. manually fixing them here
ens_clean.loc[48045, "EventDate"] = "2013-05-07"
ens_clean.loc[48051, "EventDate"] = "2013-05-22"#48051,49174
ens_clean.loc[48056, "EventDate"] = "2013-05-10"#48056,49179
ens_clean.loc[48072, "EventDate"] = "2013-05-28"#48072,49195
ens_clean.loc[48199, "EventDate"] = "2013-05-02"#48199,49151
ens_clean.loc[53357, "EventDate"] = "2013-07-16"#53357,49197, rev
ens_clean.loc[7100, "EventDate"] = "1986-11-05" #7100,6804 missing both event date and notification date
# Out:
# C:\Users\CEN1\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
#checking one to make sure it worked
ens_clean.loc[48072]
# Out:
# EventNotificationNumber                                                49195
# SiteName                                                             CATAWBA
# EventDate                                                         2013-05-28
# NotificationDate                                         2013-07-16 14:20:00
# Text                       60 DAY REPORT - INVALID ACTUATION OF SPECIFIED...
# CurrPower1                                                               100
# CurrPower2                                                               100
# CurrPower3                                                                 0
# InitPower1                                                               100
# InitPower2                                                               100
# InitPower3                                                                 0
# ImportedDate                                      2018-06-13 12:25:01.117000
# ...

# %%
ens_clean.head()
# Out:
#                      EventNotificationNumber      SiteName  \
# EventNotificationId
# 18701                                  18716  FORT CALHOUN
# 18702                                  18717     PALISADES
# 18704                                  18719    NORTH ANNA
# 18705                                  18720     MILLSTONE
# 18706                                  18721   QUAD CITIES
#
#                                EventDate    NotificationDate  \
# EventNotificationId
# 18701                1990-06-15 18:24:00 1990-06-15 18:24:00
# 18702                1990-06-15 20:10:00 1990-06-15 22:49:00
# 18704                1990-06-16 14:53:00 1990-06-16 18:47:00
# 18705                1990-06-17 01:18:00 1990-06-17 02:25:00
# 18706                1990-06-17 03:13:00 1990-06-17 04:48:00
#
#                                                                   Text  \
# EventNotificationId
# 18701                LICENSEE PLANS TO DISABLE THE CONTROL ROOM ENS...
# ...

# %%
#checking the EventDate column again for null-type values because above it shows some NaT values
(ens_clean['EventDate'] == "NaT").sum()
# Out:
# 0

# %%
ens_clean['Year'] = ens_clean['EventDate'].astype(str).str[:10]
# Out:
# C:\Users\CEN1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#ens_clean_pow['IntEventDate'] = ens_clean_pow['Year'].str.replace("-","")

# %%
#(ens_clean_pow['IntEventDate'] == "NaT").sum()

# %%
(ens_clean['Year'] == "NaT").sum()
# Out:
# 0

# %%
ens_clean.dtypes
# Out:
# EventNotificationNumber             int64
# SiteName                           object
# EventDate                          object
# NotificationDate           datetime64[ns]
# Text                               object
# CurrPower1                        float64
# CurrPower2                        float64
# CurrPower3                        float64
# InitPower1                        float64
# InitPower2                        float64
# InitPower3                        float64
# ImportedDate               datetime64[ns]
# NameAgain                          object
# Year                               object
# dtype: object

# %%
ens_clean['Year'].astype(np.datetime64)
# Out:
# EventNotificationId
# 18701   1990-06-15
# 18702   1990-06-15
# 18704   1990-06-16
# 18705   1990-06-17
# 18706   1990-06-17
#            ...
# 18695   1990-06-14
# 18696   1990-03-26
# 18697   1990-06-14
# 18698   1990-06-15
# 18699   1990-06-15
# Name: Year, Length: 39081, dtype: datetime64[ns]

# %%
ens_clean.head()
# Out:
#                      EventNotificationNumber      SiteName  \
# EventNotificationId
# 18701                                  18716  FORT CALHOUN
# 18702                                  18717     PALISADES
# 18704                                  18719    NORTH ANNA
# 18705                                  18720     MILLSTONE
# 18706                                  18721   QUAD CITIES
#
#                                EventDate    NotificationDate  \
# EventNotificationId
# 18701                1990-06-15 18:24:00 1990-06-15 18:24:00
# 18702                1990-06-15 20:10:00 1990-06-15 22:49:00
# 18704                1990-06-16 14:53:00 1990-06-16 18:47:00
# 18705                1990-06-17 01:18:00 1990-06-17 02:25:00
# 18706                1990-06-17 03:13:00 1990-06-17 04:48:00
#
#                                                                   Text  \
# EventNotificationId
# 18701                LICENSEE PLANS TO DISABLE THE CONTROL ROOM ENS...
# ...

# %%
ens_clean.columns
# Out:
# Index(['EventNotificationNumber', 'SiteName', 'EventDate', 'NotificationDate',
#        'Text', 'CurrPower1', 'CurrPower2', 'CurrPower3', 'InitPower1',
#        'InitPower2', 'InitPower3', 'ImportedDate', 'NameAgain', 'Year'],
#       dtype='object')

# %%
#making sure there are no null values
ens_clean['EventNotificationNumber'].isnull().sum()
# Out:
# 0

# %%
#making sure there are no duplicate entries
ens_clean['EventNotificationNumber'].duplicated().sum()
# Out:
# 0

# %%
#checking for how many null values in the column. Some are ok and make sense.
ens_clean['CurrPower1'].isnull().sum()
# Out:
# 13

# %%
ens_clean['CurrPower2'].isnull().sum()
# Out:
# 20

# %%
ens_clean['CurrPower3'].isnull().sum()
# Out:
# 24

# %%
ens_clean.shape
# Out:
# (39081, 14)

# %%
#I only want data from 2002 to July 1, 2020
ens_clean_dates = ens_clean.loc[ens_clean['Year'] >= '2002-01-01']
ens_clean_dates = ens_clean_dates.loc[ens_clean_dates['Year'] <= '2020-06-30']

# %%
ens_clean_dates.head()
# Out:
#                      EventNotificationNumber         SiteName  \
# EventNotificationId
# 37561                                  38782      POINT BEACH
# 37563                                  38784       PALO VERDE
# 37567                                  38788       RIVER BEND
# 37568                                  38790         LIMERICK
# 37569                                  38791  NINE MILE POINT
#
#                                EventDate    NotificationDate  \
# EventNotificationId
# 37561                2002-03-19 10:56:00 2002-03-19 14:15:00
# 37563                2002-03-15 06:30:00 2002-03-19 19:02:00
# 37567                2002-03-20 12:30:00 2002-03-20 14:27:00
# 37568                2002-03-20 15:43:00 2002-03-20 22:56:00
# 37569                2002-03-21 03:13:00 2002-03-21 10:11:00
#
#                                                                   Text  \
# EventNotificationId
# 37561                LOSS OF SPDS DEGRADES COMMUNICATION/ASSESSMENT...
# ...

# %%
ens_clean_dates.shape
# Out:
# (8732, 14)

# %%
ens_clean_dates.head()
# Out:
#                      EventNotificationNumber         SiteName  \
# EventNotificationId
# 37561                                  38782      POINT BEACH
# 37563                                  38784       PALO VERDE
# 37567                                  38788       RIVER BEND
# 37568                                  38790         LIMERICK
# 37569                                  38791  NINE MILE POINT
#
#                                EventDate    NotificationDate  \
# EventNotificationId
# 37561                2002-03-19 10:56:00 2002-03-19 14:15:00
# 37563                2002-03-15 06:30:00 2002-03-19 19:02:00
# 37567                2002-03-20 12:30:00 2002-03-20 14:27:00
# 37568                2002-03-20 15:43:00 2002-03-20 22:56:00
# 37569                2002-03-21 03:13:00 2002-03-21 10:11:00
#
#                                                                   Text  \
# EventNotificationId
# 37561                LOSS OF SPDS DEGRADES COMMUNICATION/ASSESSMENT...
# ...

# %%
ens_clean_dates.tail()
# Out:
#                      EventNotificationNumber         SiteName  \
# EventNotificationId
# 54941                                  54752          CATAWBA
# 54943                                  54753        WATTS BAR
# 54960                                  54738        MILLSTONE
# 55018                                  54820     PEACH BOTTOM
# 55072                                  54874  NINE MILE POINT
#
#                                EventDate    NotificationDate  \
# EventNotificationId
# 54941                2020-06-21 21:00:00 2020-06-22 01:00:00
# 54943                2020-06-22 13:04:00 2020-06-22 13:45:00
# 54960                2020-06-05 03:20:00 2020-06-05 10:39:00
# 55018                2020-06-08 04:24:00 2020-08-06 13:10:00
# 55072                2020-03-06 00:00:00 2020-09-01 14:48:00
#
#                                                                   Text  \
# EventNotificationId
# 54941                UNPLANNED TECHNICAL SUPPORT CENTER VENTILATION...
# ...

# %%
ens_clean_dates.sort_values(by=['Year'])
# Out:
#                      EventNotificationNumber       SiteName  \
# EventNotificationId
# 39193                                  38602  CRYSTAL RIVER
# 39192                                  38601         COOPER
# 39196                                  38605    DAVIS BESSE
# 39198                                  38607     WOLF CREEK
# 39195                                  38604         HARRIS
# ...                                      ...            ...
# 55018                                  54820   PEACH BOTTOM
# 54929                                  54742         SUMMER
# 54938                                  54749  BEAVER VALLEY
# 54941                                  54752        CATAWBA
# 54943                                  54753      WATTS BAR
#
#                                EventDate    NotificationDate  \
# EventNotificationId
# 39193                2002-01-01 09:19:00 2002-01-01 10:08:00
# 39192                2002-01-01 00:42:00 2002-01-01 09:41:00
# ...

# %%
ens_clean_dates['Quarter'] = pd.PeriodIndex(pd.to_datetime(ens_clean_dates.Year), freq='Q')

# %%
ens_clean_dates.head()
# Out:
#                      EventNotificationNumber         SiteName  \
# EventNotificationId
# 37561                                  38782      POINT BEACH
# 37563                                  38784       PALO VERDE
# 37567                                  38788       RIVER BEND
# 37568                                  38790         LIMERICK
# 37569                                  38791  NINE MILE POINT
#
#                                EventDate    NotificationDate  \
# EventNotificationId
# 37561                2002-03-19 10:56:00 2002-03-19 14:15:00
# 37563                2002-03-15 06:30:00 2002-03-19 19:02:00
# 37567                2002-03-20 12:30:00 2002-03-20 14:27:00
# 37568                2002-03-20 15:43:00 2002-03-20 22:56:00
# 37569                2002-03-21 03:13:00 2002-03-21 10:11:00
#
#                                                                   Text  \
# EventNotificationId
# 37561                LOSS OF SPDS DEGRADES COMMUNICATION/ASSESSMENT...
# ...

# %%
en = ens_clean_dates[['Quarter', 'Year', 'NameAgain', 'EventNotificationNumber']]

# %%
en.shape
# Out:
# (8732, 4)

# %%
en.head()
# Out:
#                     Quarter        Year          NameAgain  \
# EventNotificationId
# 37561                2002Q1  2002-03-19      POINT BEACH 2
# 37563                2002Q1  2002-03-15       PALO VERDE 1
# 37567                2002Q1  2002-03-20       RIVER BEND 1
# 37568                2002Q1  2002-03-20         LIMERICK 1
# 37569                2002Q1  2002-03-21  NINE MILE POINT 2
#
#                      EventNotificationNumber
# EventNotificationId
# 37561                                  38782
# 37563                                  38784
# 37567                                  38788
# 37568                                  38790
# 37569                                  38791

# %%
#ensclean = en.groupby(['Quarter', 'NameAgain']).count()['NameAgain']
ensclean = en.groupby(by=['Quarter', 'NameAgain']).agg(ENCount = pd.NamedAgg(column = "NameAgain", aggfunc ="count"))

# %%
ensclean.head()
# Out:
#                          ENCount
# Quarter NameAgain
# 2002Q1  BEAVER VALLEY 1        1
#         BEAVER VALLEY 2        1
#         BROWNS FERRY 2         1
#         BROWNS FERRY 3         2
#         BRUNSWICK 2            1

# %%
ensclean.tail()
# Out:
#                        ENCount
# Quarter NameAgain
# 2020Q2  SURRY 1              1
#         SUSQUEHANNA 1        1
#         WATERFORD 3          2
#         WATTS BAR 1          2
#         WATTS BAR 2          1

# %%
ensclean.shape
# Out:
# (4277, 1)

# %%
#create a new Excel file with just the cleaned up data we want
ensclean.to_excel('ENdata.xlsx')
